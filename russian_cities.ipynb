# %%
import pandas as pd

# %%
# df = pd.read_csv("files/cities_russia.csv")
df = pd.read_excel("files/города_России.xlsx", sheet_name="cities_russia")
df
# Out:
#          N      Город                Регион Федеральный_округ  Население  \
# 0        1      Абаза               Хакасия         Сибирский      12272
# 1        2     Абакан               Хакасия         Сибирский     184769
# 2        3   Абдулино  Оренбургская область       Приволжский      17274
# 3        4     Абинск    Краснодарский край             Южный      39511
# 4        5    Агидель          Башкортостан       Приволжский      14219
# ...    ...        ...                   ...               ...        ...
# 1120  1121  Ярославль   Ярославская область       Центральный     577279
# 1121  1122     Ярцево    Смоленская область       Центральный      41452
# 1122  1123  Ясногорск      Тульская область       Центральный      15269
# 1123  1124      Ясный  Оренбургская область       Приволжский      15471
# 1124  1125     Яхрома    Московская область       Центральный      14011
#
#      Основан Статус_города                           Прежние_названия
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1125 entries, 0 to 1124
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   N                  1125 non-null   int64
#  1   Город              1125 non-null   object
#  2   Регион             1125 non-null   object
#  3   Федеральный_округ  1125 non-null   object
#  4   Население          1125 non-null   int64
#  5   Основан            1125 non-null   object
#  6   Статус_города      1122 non-null   object
#  7   Прежние_названия   592 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 70.4+ KB
