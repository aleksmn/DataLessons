# %% [markdown]
# # График курсов валют

# %%
# !pip install yfinance
# !pip install matplotlib

# %%
import yfinance as yf

# %% [markdown]
# Получаем биржевой тикер курса рубля к доллару

# %%
rub_usd = yf.Ticker("RUB=X")

# %% [markdown]
# Получаем данные курса за последний месяц

# %%
data = rub_usd.history()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 24 entries, 2024-07-16 00:00:00+01:00 to 2024-08-16 00:00:00+01:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          24 non-null     float64
#  1   High          24 non-null     float64
#  2   Low           24 non-null     float64
#  3   Close         24 non-null     float64
#  4   Volume        24 non-null     int64
#  5   Dividends     24 non-null     float64
#  6   Stock Splits  24 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 1.5 KB

# %% [markdown]
# Настраиваем интервал в ручную

# %%
data = rub_usd.history(interval='1d', start='2023-08-01', end='2024-08-01')
data
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2023-08-01 00:00:00+01:00  91.614998  92.196999  91.311501  91.614998       0
# 2023-08-02 00:00:00+01:00  92.375000  94.411499  91.952499  92.375000       0
# 2023-08-03 00:00:00+01:00  94.014999  94.665001  93.075996  94.014999       0
# 2023-08-04 00:00:00+01:00  94.964996  97.360001  94.143501  94.964996       0
# 2023-08-07 00:00:00+01:00  95.839996  97.010002  95.188004  95.839996       0
# ...                              ...        ...        ...        ...     ...
# 2024-07-25 00:00:00+01:00  86.240082  86.819939  84.842316  86.236908       0
# 2024-07-26 00:00:00+01:00  84.993896  86.278801  84.978210  84.994286       0
# 2024-07-29 00:00:00+01:00  85.003456  86.825668  84.866219  84.995621       0
# 2024-07-30 00:00:00+01:00  86.393066  86.701439  85.818886  86.395805       0
# 2024-07-31 00:00:00+01:00  85.746674  86.569267  84.983788  85.747467       0
#
# ...

# %% [markdown]
# Получаем даты с помощью модуля datetime

# %%
import datetime
datetime.datetime.today()
datetime.datetime.today() - datetime.timedelta(days=365)
# Out:
# datetime.datetime(2023, 8, 17, 13, 39, 26, 758250)

# %%
data = rub_usd.history(interval='1d', start=datetime.datetime.today() - datetime.timedelta(days=365), end=datetime.datetime.today())
data
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2023-08-17 00:00:00+01:00  97.315002  97.315002  92.132500  94.463997       0
# 2023-08-18 00:00:00+01:00  94.464996  94.464996  92.470001  94.464996       0
# 2023-08-21 00:00:00+01:00  95.165001  95.165001  92.651497  95.165001       0
# 2023-08-22 00:00:00+01:00  93.464996  94.687500  93.464996  93.464996       0
# 2023-08-23 00:00:00+01:00  94.464996  94.918999  93.502502  94.464996       0
# ...                              ...        ...        ...        ...     ...
# 2024-08-12 00:00:00+01:00  86.914871  91.800957  86.867508  86.799545       0
# 2024-08-13 00:00:00+01:00  90.998436  93.747124  90.975548  90.995522       0
# 2024-08-14 00:00:00+01:00  90.493446  92.997658  88.001091  90.496338       0
# 2024-08-15 00:00:00+01:00  89.795944  90.488571  88.243538  89.795135       0
# 2024-08-16 00:00:00+01:00  88.475998  89.475998  87.724998  88.879997       0
#
# ...

# %% [markdown]
# Выбираем данные для графика

# %%
data.Open
# Out:
# Date
# 2023-08-17 00:00:00+01:00    97.315002
# 2023-08-18 00:00:00+01:00    94.464996
# 2023-08-21 00:00:00+01:00    95.165001
# 2023-08-22 00:00:00+01:00    93.464996
# 2023-08-23 00:00:00+01:00    94.464996
#                                ...
# 2024-08-12 00:00:00+01:00    86.914871
# 2024-08-13 00:00:00+01:00    90.998436
# 2024-08-14 00:00:00+01:00    90.493446
# 2024-08-15 00:00:00+01:00    89.795944
# 2024-08-16 00:00:00+01:00    88.475998
# Name: Open, Length: 261, dtype: float64

# %%
data.index
# Out:
# DatetimeIndex(['2023-08-17 00:00:00+01:00', '2023-08-18 00:00:00+01:00',
#                '2023-08-21 00:00:00+01:00', '2023-08-22 00:00:00+01:00',
#                '2023-08-23 00:00:00+01:00', '2023-08-24 00:00:00+01:00',
#                '2023-08-25 00:00:00+01:00', '2023-08-28 00:00:00+01:00',
#                '2023-08-29 00:00:00+01:00', '2023-08-30 00:00:00+01:00',
#                ...
#                '2024-08-05 00:00:00+01:00', '2024-08-06 00:00:00+01:00',
#                '2024-08-07 00:00:00+01:00', '2024-08-08 00:00:00+01:00',
#                '2024-08-09 00:00:00+01:00', '2024-08-12 00:00:00+01:00',
#                '2024-08-13 00:00:00+01:00', '2024-08-14 00:00:00+01:00',
#                '2024-08-15 00:00:00+01:00', '2024-08-16 00:00:00+01:00'],
#               dtype='datetime64[ns, Europe/London]', name='Date', length=261, freq=None)

# %% [markdown]
# Строим график с использование matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data.index, data.Open)

# %% [markdown]
# Собираем все вместе:

# %%
import yfinance as yf
import matplotlib.pyplot as plt
import datetime

plt.style.use('dark_background')

start_date = datetime.datetime.today() - datetime.timedelta(days=365)
end_date = datetime.datetime.today()

ticker_name = "RUB=X"

# Ввод от пользователя
# ticker_name = input("Введите тикер для графика: ") or "RUB=X"

ticker = yf.Ticker(ticker_name)

data = rub_usd.history(interval='1d', start=start_date, end=end_date)

plt.figure(figsize=(10, 5), layout="constrained")

plt.plot(data.index, data.Open)

plt.title(ticker_name)

plt.show()

# %%
# Доступные стили
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']
